# %% [markdown]
# # String Length Out Of Bounds

# %%
from deepchecks.checks.integrity.string_length_out_of_bounds import StringLengthOutOfBounds
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
col1 = ["aaaaa33", "aaaaaaa33"]*40
col1.append("a")
col1.append("aaaaaadsfasdfasdf")

col2 = ["b", "abc"]*41

col3 = ["a"]*80
col3.append("a"*100)
col3.append("a"*200)
# col1 and col3 contrains outliers, col2 does not
df = pd.DataFrame({"col1":col1, "col2": col2, "col3": col3 })

# %%
StringLengthOutOfBounds().run(df)
# Out:
# 8.0
# upper 6
# 2.0
# 8.0
# lower 8
# 5
# lower 99
# /Users/dbi/git/deepchecks/deepchecks/utils/features.py:95: UserWarning:
#
# Features importance where not calculated:
# Model must inherit from one of supported models: sklearn.base.BaseEstimator or CatBoost, Recived: NoneType
# <h4>String Length Out Of Bounds</h4>
# <p>Detect strings with length that is much longer/shorter than the identified "normal" string lengths.</p>
# <style type="text/css">
# #T_599e6_ table {
#   text-align: left;
# }
# #T_599e6_ thead {
#   text-align: left;
# }
# #T_599e6_ tbody {
#   text-align: left;
# }
# #T_599e6_ th {
#   text-align: left;
# }
# #T_599e6_ td {
#   text-align: left;
# }
# </style>
# <table id="T_599e6_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Outlier Samples</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column Name</th>
#       <th class="index_name level1" >Range of Detected Normal String Lengths</th>
#       <th class="index_name level2" >Range of Detected Outlier String Lengths</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_599e6_level0_row0" class="row_heading level0 row0" >col1</th>
#       <th id="T_599e6_level1_row0" class="row_heading level1 row0" >7 - 9</th>
#       <th id="T_599e6_level2_row0" class="row_heading level2 row0" >17 - 17</th>
#       <td id="T_599e6_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_599e6_level0_row1" class="row_heading level0 row1" >col3</th>
#       <th id="T_599e6_level1_row1" class="row_heading level1 row1" >1 - 1</th>
#       <th id="T_599e6_level2_row1" class="row_heading level2 row1" >100 - 200</th>
#       <td id="T_599e6_row1_col0" class="data row1 col0" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
col = ["a","a","a","a","a","a","a","a","a","a","a","a","a","ab","ab","ab","ab","ab","ab", "ab"]*1000
col.append("basdbadsbaaaaaaaaaa")
col.append("basdbadsbaaaaaaaaaaa")
df = pd.DataFrame({"col1":col})
StringLengthOutOfBounds(num_percentiles=1000).run(df)
# Out:
# 5
# lower 17
# /Users/dbi/git/deepchecks/deepchecks/utils/features.py:95: UserWarning:
#
# Features importance where not calculated:
# Model must inherit from one of supported models: sklearn.base.BaseEstimator or CatBoost, Recived: NoneType
# <h4>String Length Out Of Bounds</h4>
# <p>Detect strings with length that is much longer/shorter than the identified "normal" string lengths.</p>
# <style type="text/css">
# #T_58810_ table {
#   text-align: left;
# }
# #T_58810_ thead {
#   text-align: left;
# }
# #T_58810_ tbody {
#   text-align: left;
# }
# #T_58810_ th {
#   text-align: left;
# }
# #T_58810_ td {
#   text-align: left;
# }
# </style>
# <table id="T_58810_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Outlier Samples</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column Name</th>
#       <th class="index_name level1" >Range of Detected Normal String Lengths</th>
#       <th class="index_name level2" >Range of Detected Outlier String Lengths</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58810_level0_row0" class="row_heading level0 row0" >col1</th>
#       <th id="T_58810_level1_row0" class="row_heading level1 row0" >1 - 2</th>
#       <th id="T_58810_level2_row0" class="row_heading level2 row0" >19 - 20</th>
#       <td id="T_58810_row0_col0" class="data row0 col0" >2</td>
#     </tr>
#   </tbody>
# </table>
