# %% [markdown]
# # Model Info

# %%
from sklearn.ensemble import AdaBoostClassifier
from deepchecks.checks.overview import ModelInfo

clf = AdaBoostClassifier(learning_rate=1.2)
ModelInfo().run(clf)
# Out:
# <h4>Model Info</h4>
# <p>Summarize given model parameters.</p>
# Model Type: AdaBoostClassifier
# <style type="text/css">
# #T_e2857_ table {
#   text-align: left;
# }
# #T_e2857_ thead {
#   text-align: left;
# }
# #T_e2857_ tbody {
#   text-align: left;
# }
# #T_e2857_ th {
#   text-align: left;
# }
# #T_e2857_ td {
#   text-align: left;
# }
# #T_e2857_row2_col0, #T_e2857_row2_col1, #T_e2857_row2_col2 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_e2857_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Parameter</th>
#       <th class="col_heading level0 col1" >Value</th>
#       <th class="col_heading level0 col2" >Default</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e2857_row0_col0" class="data row0 col0" >algorithm</td>
#       <td id="T_e2857_row0_col1" class="data row0 col1" >SAMME.R</td>
#       <td id="T_e2857_row0_col2" class="data row0 col2" >SAMME.R</td>
#     </tr>
#     <tr>
#       <td id="T_e2857_row1_col0" class="data row1 col0" >base_estimator</td>
#       <td id="T_e2857_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_e2857_row1_col2" class="data row1 col2" >None</td>
#     </tr>
#     <tr>
#       <td id="T_e2857_row2_col0" class="data row2 col0" >learning_rate</td>
#       <td id="T_e2857_row2_col1" class="data row2 col1" >1.20</td>
#       <td id="T_e2857_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_e2857_row3_col0" class="data row3 col0" >n_estimators</td>
#       <td id="T_e2857_row3_col1" class="data row3 col1" >50</td>
#       <td id="T_e2857_row3_col2" class="data row3 col2" >50</td>
#     </tr>
#     <tr>
#       <td id="T_e2857_row4_col0" class="data row4 col0" >random_state</td>
#       <td id="T_e2857_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_e2857_row4_col2" class="data row4 col2" >None</td>
#     </tr>
#   </tbody>
# </table>
# <p style="font-size:0.7em"><i>Colored rows are parameters with non-default values</i></p>
