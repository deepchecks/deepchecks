# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mlchecks.checks import string_mismatch
import pandas as pd

# %%
data = {'col1': ['Deep', 'deep', 'deep!!!', '$deeP$', 'earth', 'foo', 'bar', 'foo?']}
df = pd.DataFrame(data=data)
string_mismatch(df)
# Out:
# /Users/matan/deepchecksv2/mlchecks/mlchecks/base/dataset.py:62: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._features = [x for x in df.columns if x not in {label, index, date}]
# /Users/matan/deepchecksv2/mlchecks/mlchecks/base/dataset.py:72: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._cat_features = self.infer_categorical_features()
#                          Value  Count  Fraction of data
# Column Name Base form
# col1        deep       deep!!!      1              0.12
#             deep        $deeP$      1              0.12
#             deep          Deep      1              0.12
#             deep          deep      1              0.12
#             foo           foo?      1              0.12
#             foo            foo      1              0.12
