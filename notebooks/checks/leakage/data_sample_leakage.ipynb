# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from mlchecks.checks.leakage import DataSampleLeakageReport
from mlchecks.base import Dataset

# %% [markdown]
# # Generating data:

# %%
iris = load_iris(return_X_y=False, as_frame=True)
X = iris.data
import numpy as np

y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=55)
train_dataset = Dataset(pd.concat([X_train, y_train], axis=1), 
            features=iris.feature_names,
            label='target')
test_df = pd.concat([X_test, y_test], axis=1)
bad_test = test_df.append(train_dataset.data.iloc[[0, 1, 2, 3, 4]], ignore_index=True)
                    
validation_dataset = Dataset(bad_test, 
            features=iris.feature_names,
            label='target')

# %% [markdown]
# # Running data_sample_leakage_report check:

# %%
check = DataSampleLeakageReport()

# %%
check.run(validation_dataset=validation_dataset, train_dataset=train_dataset)
# Out:
# <h4>Data Sample Leakage Report</h4>
# <p>Find what percent of the validation data is in the train data.</p>
# 10.00% (5 / 50)                      of validation data samples appear in train data
# <style type="text/css">
# #T_da13a_ th {
#   text-align: left;
# }
# #T_da13a_ td {
#   text-align: left;
# }
# </style>
# <table id="T_da13a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sepal length (cm)</th>
#       <th class="col_heading level0 col1" >sepal width (cm)</th>
#       <th class="col_heading level0 col2" >petal length (cm)</th>
#       <th class="col_heading level0 col3" >petal width (cm)</th>
#       <th class="col_heading level0 col4" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da13a_level0_row0" class="row_heading level0 row0" >Train indexes: 23</th>
#       <td id="T_da13a_row0_col0" class="data row0 col0" >5.100000</td>
#       <td id="T_da13a_row0_col1" class="data row0 col1" >3.300000</td>
#       <td id="T_da13a_row0_col2" class="data row0 col2" >1.700000</td>
#       <td id="T_da13a_row0_col3" class="data row0 col3" >0.500000</td>
#       <td id="T_da13a_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row1" class="row_heading level0 row1" >Validation indexes: 48</th>
#       <td id="T_da13a_row1_col0" class="data row1 col0" >5.100000</td>
#       <td id="T_da13a_row1_col1" class="data row1 col1" >3.300000</td>
#       <td id="T_da13a_row1_col2" class="data row1 col2" >1.700000</td>
#       <td id="T_da13a_row1_col3" class="data row1 col3" >0.500000</td>
#       <td id="T_da13a_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row2" class="row_heading level0 row2" >Train indexes: 101, 142</th>
#       <td id="T_da13a_row2_col0" class="data row2 col0" >5.800000</td>
#       <td id="T_da13a_row2_col1" class="data row2 col1" >2.700000</td>
#       <td id="T_da13a_row2_col2" class="data row2 col2" >5.100000</td>
#       <td id="T_da13a_row2_col3" class="data row2 col3" >1.900000</td>
#       <td id="T_da13a_row2_col4" class="data row2 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row3" class="row_heading level0 row3" >Validation indexes: 45</th>
#       <td id="T_da13a_row3_col0" class="data row3 col0" >5.800000</td>
#       <td id="T_da13a_row3_col1" class="data row3 col1" >2.700000</td>
#       <td id="T_da13a_row3_col2" class="data row3 col2" >5.100000</td>
#       <td id="T_da13a_row3_col3" class="data row3 col3" >1.900000</td>
#       <td id="T_da13a_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row4" class="row_heading level0 row4" >Train indexes: 115</th>
#       <td id="T_da13a_row4_col0" class="data row4 col0" >6.400000</td>
#       <td id="T_da13a_row4_col1" class="data row4 col1" >3.200000</td>
#       <td id="T_da13a_row4_col2" class="data row4 col2" >5.300000</td>
#       <td id="T_da13a_row4_col3" class="data row4 col3" >2.300000</td>
#       <td id="T_da13a_row4_col4" class="data row4 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row5" class="row_heading level0 row5" >Validation indexes: 49</th>
#       <td id="T_da13a_row5_col0" class="data row5 col0" >6.400000</td>
#       <td id="T_da13a_row5_col1" class="data row5 col1" >3.200000</td>
#       <td id="T_da13a_row5_col2" class="data row5 col2" >5.300000</td>
#       <td id="T_da13a_row5_col3" class="data row5 col3" >2.300000</td>
#       <td id="T_da13a_row5_col4" class="data row5 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row6" class="row_heading level0 row6" >Train indexes: 110</th>
#       <td id="T_da13a_row6_col0" class="data row6 col0" >6.500000</td>
#       <td id="T_da13a_row6_col1" class="data row6 col1" >3.200000</td>
#       <td id="T_da13a_row6_col2" class="data row6 col2" >5.100000</td>
#       <td id="T_da13a_row6_col3" class="data row6 col3" >2.000000</td>
#       <td id="T_da13a_row6_col4" class="data row6 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row7" class="row_heading level0 row7" >Validation indexes: 47</th>
#       <td id="T_da13a_row7_col0" class="data row7 col0" >6.500000</td>
#       <td id="T_da13a_row7_col1" class="data row7 col1" >3.200000</td>
#       <td id="T_da13a_row7_col2" class="data row7 col2" >5.100000</td>
#       <td id="T_da13a_row7_col3" class="data row7 col3" >2.000000</td>
#       <td id="T_da13a_row7_col4" class="data row7 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row8" class="row_heading level0 row8" >Train indexes: 131</th>
#       <td id="T_da13a_row8_col0" class="data row8 col0" >7.900000</td>
#       <td id="T_da13a_row8_col1" class="data row8 col1" >3.800000</td>
#       <td id="T_da13a_row8_col2" class="data row8 col2" >6.400000</td>
#       <td id="T_da13a_row8_col3" class="data row8 col3" >2.000000</td>
#       <td id="T_da13a_row8_col4" class="data row8 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da13a_level0_row9" class="row_heading level0 row9" >Validation indexes: 46</th>
#       <td id="T_da13a_row9_col0" class="data row9 col0" >7.900000</td>
#       <td id="T_da13a_row9_col1" class="data row9 col1" >3.800000</td>
#       <td id="T_da13a_row9_col2" class="data row9 col2" >6.400000</td>
#       <td id="T_da13a_row9_col3" class="data row9 col3" >2.000000</td>
#       <td id="T_da13a_row9_col4" class="data row9 col4" >2</td>
#     </tr>
#   </tbody>
# </table>
