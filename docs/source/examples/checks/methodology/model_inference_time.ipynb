# %% [markdown]
# # Model Inference Time

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split

from deepchecks import Dataset
from deepchecks.checks.methodology import ModelInferenceTimeCheck

# %%
iris = load_iris(as_frame=True)
train, test = train_test_split(iris.frame, test_size=0.33, random_state=42)

train_ds = Dataset(train, features=iris.feature_names, label='target')
test_ds = Dataset(test, features=iris.feature_names, label='target')

clf = AdaBoostClassifier().fit(train_ds.features_columns, train_ds.label_col)

# %%
# NBVAL_SKIP
check = ModelInferenceTimeCheck()
check.run(test_ds, clf)
# Out:
# <h4>Model Inference Time Check</h4><p>Measure model average inference time (in seconds) per sample.</p><h5>Additional Outputs</h5><div>Average model inference time for one sample (in seconds): 0.00018137</div>

# %% [markdown]
# ## Instantiating check instance with condition

# %%
# NBVAL_SKIP
check = ModelInferenceTimeCheck().add_condition_inference_time_is_not_greater_than(0.00001)
check.run(test_ds, clf)
# Out:
# <h4>Model Inference Time Check</h4><p>Measure model average inference time (in seconds) per sample.</p><h5>Conditions Summary</h5><style type="text/css">
# #T_2debb_ table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_2debb_ thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_2debb_ tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_2debb_ th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_2debb_ td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_2debb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Status</th>
#       <th class="col_heading level0 col1" >Condition</th>
#       <th class="col_heading level0 col2" >More Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2debb_row0_col0" class="data row0 col0" ><div style="color: red;text-align: center">✖</div></td>
#       <td id="T_2debb_row0_col1" class="data row0 col1" >Average model inference time for one sample is not greater than 1e-05</td>
#       <td id="T_2debb_row0_col2" class="data row0 col2" >Found average inference time (in seconds) above threshold: 0.00015357</td>
#     </tr>
#   </tbody>
# </table>
# <h5>Additional Outputs</h5><div>Average model inference time for one sample (in seconds): 0.00015357</div>
