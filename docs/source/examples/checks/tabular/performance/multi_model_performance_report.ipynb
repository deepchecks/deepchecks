# %% [markdown]
# # Multi Model Performance Report

# %% [markdown]
# ## Multiclass

# %%
from deepchecks.tabular.base import Dataset
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from deepchecks.tabular.checks.performance import MultiModelPerformanceReport

# %%
iris = load_iris(as_frame=True)
train, test = train_test_split(iris.frame, test_size=0.33, random_state=42)

train_ds = Dataset(train, label="target")
test_ds = Dataset(test, label="target")

features = train_ds.data[train_ds.features]
label = train_ds.data[train_ds.label_name]
clf1 = AdaBoostClassifier().fit(features, label)
clf2 = RandomForestClassifier().fit(features, label)
clf3 = DecisionTreeClassifier().fit(features, label)

# %%
MultiModelPerformanceReport().run(train_ds, test_ds, [clf1, clf2, clf3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in _ipython_display_(self, unique_id, as_widget, show_additional_outputs)
#     269     def _ipython_display_(self, unique_id=None, as_widget=False,
#     270                           show_additional_outputs=True):
# --> 271         check_widget = self.display_check(unique_id=unique_id, as_widget=as_widget,
#     272                                           show_additional_outputs=show_additional_outputs,)
#     273         if as_widget:
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in display_check(self, unique_id, as_widget, show_additional_outputs)
#     130             check_html += f'<h4 id="{check_id}">{self.get_header()}</h4>'
#     131         else:
# --> 132             check_html += f'<h4>{self.get_header()}</h4>'
#     133         if hasattr(self.check.__class__, '__doc__'):
#     134             summary = get_docs_summary(self.check)
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in get_header(self)
#     280     def get_header(self):
#     281         """Return header for display. if header was defined return it, else extract name of check class."""
# --> 282         return self.header or self.check.name()
#     283
#     284     def process_conditions(self):
#
# AttributeError: 'CheckResult' object has no attribute 'check'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in __repr__(self)
#     276     def __repr__(self):
#     277         """Return default __repr__ function uses value."""
# --> 278         return f'{self.get_header()}: {self.value}'
#     279
#     280     def get_header(self):
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in get_header(self)
#     280     def get_header(self):
#     281         """Return header for display. if header was defined return it, else extract name of check class."""
# --> 282         return self.header or self.check.name()
#     283
#     284     def process_conditions(self):
#
# AttributeError: 'CheckResult' object has no attribute 'check'

# %% [markdown]
# ## Regression

# %%
from sklearn.datasets import load_diabetes
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
diabetes = load_diabetes(as_frame=True)
train, test = train_test_split(diabetes.frame, test_size=0.33, random_state=42)

train_ds = Dataset(train, label="target", cat_features=['sex'])
test_ds = Dataset(test, label="target", cat_features=['sex'])

features = train_ds.data[train_ds.features]
label = train_ds.data[train_ds.label_name]
clf1 = AdaBoostRegressor().fit(features, label)
clf2 = RandomForestRegressor().fit(features, label)
clf3 = DecisionTreeRegressor().fit(features, label)

# %%
MultiModelPerformanceReport().run(train_ds, test_ds, [clf1, clf2, clf3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in _ipython_display_(self, unique_id, as_widget, show_additional_outputs)
#     269     def _ipython_display_(self, unique_id=None, as_widget=False,
#     270                           show_additional_outputs=True):
# --> 271         check_widget = self.display_check(unique_id=unique_id, as_widget=as_widget,
#     272                                           show_additional_outputs=show_additional_outputs,)
#     273         if as_widget:
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in display_check(self, unique_id, as_widget, show_additional_outputs)
#     130             check_html += f'<h4 id="{check_id}">{self.get_header()}</h4>'
#     131         else:
# --> 132             check_html += f'<h4>{self.get_header()}</h4>'
#     133         if hasattr(self.check.__class__, '__doc__'):
#     134             summary = get_docs_summary(self.check)
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in get_header(self)
#     280     def get_header(self):
#     281         """Return header for display. if header was defined return it, else extract name of check class."""
# --> 282         return self.header or self.check.name()
#     283
#     284     def process_conditions(self):
#
# AttributeError: 'CheckResult' object has no attribute 'check'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in __repr__(self)
#     276     def __repr__(self):
#     277         """Return default __repr__ function uses value."""
# --> 278         return f'{self.get_header()}: {self.value}'
#     279
#     280     def get_header(self):
#
# ~/work/deepchecks/deepchecks/deepchecks/core/check.py in get_header(self)
#     280     def get_header(self):
#     281         """Return header for display. if header was defined return it, else extract name of check class."""
# --> 282         return self.header or self.check.name()
#     283
#     284     def process_conditions(self):
#
# AttributeError: 'CheckResult' object has no attribute 'check'
