# %% [markdown]
# # String Length Out Of Bounds

# %%
from deepchecks.checks.integrity.string_length_out_of_bounds import StringLengthOutOfBounds
import pandas as pd

# %%
col1 = ["aaaaa33", "aaaaaaa33"]*40
col1.append("a")
col1.append("aaaaaadsfasdfasdf")

col2 = ["b", "abc"]*41

col3 = ["a"]*80
col3.append("a"*100)
col3.append("a"*200)
# col1 and col3 contrains outliers, col2 does not
df = pd.DataFrame({"col1":col1, "col2": col2, "col3": col3 })

# %%
StringLengthOutOfBounds(min_unique_value_ratio=0.01).run(df)
# Out:
# <h4>String Length Out Of Bounds</h4><p>Detect strings with length that is much longer/shorter than the identified "normal" string lengths.</p><h5>Additional Outputs</h5><div>* showing only the top 10 columns, you can change it using n_top_columns param</div><style type="text/css">
# #T_b5686_ table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_b5686_ thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_b5686_ tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_b5686_ th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_b5686_ td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_b5686_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Outlier Samples</th>
#       <th class="col_heading level0 col1" >Example Samples</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column Name</th>
#       <th class="index_name level1" >Range of Detected Normal String Lengths</th>
#       <th class="index_name level2" >Range of Detected Outlier String Lengths</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5686_level0_row0" class="row_heading level0 row0" rowspan="2">col1</th>
#       <th id="T_b5686_level1_row0" class="row_heading level1 row0" rowspan="2">7 - 9</th>
#       <th id="T_b5686_level2_row0" class="row_heading level2 row0" >1 - 1</th>
#       <td id="T_b5686_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b5686_row0_col1" class="data row0 col1" >['a']</td>
#     </tr>
#     <tr>
#       <th id="T_b5686_level2_row1" class="row_heading level2 row1" >17 - 17</th>
#       <td id="T_b5686_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b5686_row1_col1" class="data row1 col1" >['aaaaaadsfasdfasdf']</td>
#     </tr>
#     <tr>
#       <th id="T_b5686_level0_row2" class="row_heading level0 row2" >col3</th>
#       <th id="T_b5686_level1_row2" class="row_heading level1 row2" >1 - 1</th>
#       <th id="T_b5686_level2_row2" class="row_heading level2 row2" >100 - 200</th>
#       <td id="T_b5686_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b5686_row2_col1" class="data row2 col1" >['aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...', 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...']</td>
#     </tr>
#   </tbody>
# </table>

# %%
col = ["a","a","a","a","a","a","a","a","a","a","a","a","a","ab","ab","ab","ab","ab","ab", "ab"]*1000
col.append("basdbadsbaaaaaaaaaa")
col.append("basdbadsbaaaaaaaaaaa")
df = pd.DataFrame({"col1":col})
StringLengthOutOfBounds(num_percentiles=1000, min_unique_values=3).run(df)
# Out:
# <h4>String Length Out Of Bounds</h4><p>Detect strings with length that is much longer/shorter than the identified "normal" string lengths.</p><h5>Additional Outputs</h5><div>* showing only the top 10 columns, you can change it using n_top_columns param</div><style type="text/css">
# #T_93bd6_ table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_93bd6_ thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_93bd6_ tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_93bd6_ th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_93bd6_ td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_93bd6_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Outlier Samples</th>
#       <th class="col_heading level0 col1" >Example Samples</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Column Name</th>
#       <th class="index_name level1" >Range of Detected Normal String Lengths</th>
#       <th class="index_name level2" >Range of Detected Outlier String Lengths</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93bd6_level0_row0" class="row_heading level0 row0" >col1</th>
#       <th id="T_93bd6_level1_row0" class="row_heading level1 row0" >1 - 2</th>
#       <th id="T_93bd6_level2_row0" class="row_heading level2 row0" >19 - 20</th>
#       <td id="T_93bd6_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_93bd6_row0_col1" class="data row0 col1" >['basdbadsbaaaaaaaaaa', 'basdbadsbaaaaaaaaaaa']</td>
#     </tr>
#   </tbody>
# </table>
