# %% [markdown]
# # New Label

# %%
from deepchecks.checks.integrity.new_label import NewLabelTrainTest
from deepchecks.base import Dataset
import pandas as pd
# Out:
# /home/runner/work/deepchecks/deepchecks/venv/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning:
#
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
test_data = {"col1": [0, 1, 2, 3] * 10}
val_data = {"col1": [4, 5, 6, 7, 8, 9] * 10}
test = Dataset(pd.DataFrame(data=test_data), label="col1", label_type="classification_label")
val = Dataset(pd.DataFrame(data=val_data), label="col1", label_type="classification_label")

# %%
NewLabelTrainTest().run(test, val)
# Out:
# /home/runner/work/deepchecks/deepchecks/deepchecks/base/display_pandas.py:54: FutureWarning:
#
# this method is deprecated in favour of `Styler.to_html()`
# <h4>New Label Train Test</h4><p>Find new labels in test. <a href="https://docs.deepchecks.com/en/0.3.2/examples/checks/integrity/new_label.html?utm_source=display_output&utm_medium=referral&utm_campaign=check_link" target="_blank">Read More...</a></p><h5>Additional Outputs</h5><style type="text/css">
# #T_468fb table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_468fb thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_468fb tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_468fb th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_468fb td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_468fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_468fb_level0_col0" class="col_heading level0 col0" >Percent new labels in sample</th>
#       <th id="T_468fb_level0_col1" class="col_heading level0 col1" >New labels</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Label column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_468fb_level0_row0" class="row_heading level0 row0" >col1</th>
#       <td id="T_468fb_row0_col0" class="data row0 col0" >100%</td>
#       <td id="T_468fb_row0_col1" class="data row0 col1" >[4, 5, 6, 7, 8, 9]</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_data = {"col1": ["a", "b", "a", "c"] * 10, "col2": [1,2,2,3]*10}
val_data = {"col1": ["a","b","d"] * 10, "col2": [1, 4, 5]*10}
test = Dataset(pd.DataFrame(data=test_data), label="col2", label_type="classification_label")
val = Dataset(pd.DataFrame(data=val_data), label="col2", label_type="classification_label")

# %%
NewLabelTrainTest().run(test, val)
# Out:
# /home/runner/work/deepchecks/deepchecks/deepchecks/base/display_pandas.py:54: FutureWarning:
#
# this method is deprecated in favour of `Styler.to_html()`
# <h4>New Label Train Test</h4><p>Find new labels in test. <a href="https://docs.deepchecks.com/en/0.3.2/examples/checks/integrity/new_label.html?utm_source=display_output&utm_medium=referral&utm_campaign=check_link" target="_blank">Read More...</a></p><h5>Additional Outputs</h5><style type="text/css">
# #T_baa0f table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_baa0f thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_baa0f tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_baa0f th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_baa0f td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_baa0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baa0f_level0_col0" class="col_heading level0 col0" >Percent new labels in sample</th>
#       <th id="T_baa0f_level0_col1" class="col_heading level0 col1" >New labels</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Label column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baa0f_level0_row0" class="row_heading level0 row0" >col2</th>
#       <td id="T_baa0f_row0_col0" class="data row0 col0" >66.67%</td>
#       <td id="T_baa0f_row0_col1" class="data row0 col1" >[4, 5]</td>
#     </tr>
#   </tbody>
# </table>
