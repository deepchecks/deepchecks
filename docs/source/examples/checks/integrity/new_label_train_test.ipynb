# %% [markdown]
# # New Label

# %%
from deepchecks.checks.integrity.new_label import NewLabelTrainTest
from deepchecks.base import Dataset
import pandas as pd

# %%
test_data = {"col1": [0, 1, 2, 3] * 10}
val_data = {"col1": [4, 5, 6, 7, 8, 9] * 10}
test = Dataset(pd.DataFrame(data=test_data), label="col1", label_type="classification_label")
val = Dataset(pd.DataFrame(data=val_data), label="col1", label_type="classification_label")

# %%
NewLabelTrainTest().run(test, val)
# Out:
# <h4>New Label Train Test</h4><p>Find new labels in test.</p><h5>Additional Outputs</h5><style type="text/css">
# #T_dafaa_ table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_dafaa_ thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_dafaa_ tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_dafaa_ th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_dafaa_ td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_dafaa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Percent new labels in sample</th>
#       <th class="col_heading level0 col1" >New labels</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Label column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dafaa_level0_row0" class="row_heading level0 row0" >col1</th>
#       <td id="T_dafaa_row0_col0" class="data row0 col0" >100%</td>
#       <td id="T_dafaa_row0_col1" class="data row0 col1" >[4, 5, 6, 7, 8, 9]</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_data = {"col1": ["a", "b", "a", "c"] * 10, "col2": [1,2,2,3]*10}
val_data = {"col1": ["a","b","d"] * 10, "col2": [1, 4, 5]*10}
test = Dataset(pd.DataFrame(data=test_data), label="col2", label_type="classification_label")
val = Dataset(pd.DataFrame(data=val_data), label="col2", label_type="classification_label")

# %%
NewLabelTrainTest().run(test, val)
# Out:
# <h4>New Label Train Test</h4><p>Find new labels in test.</p><h5>Additional Outputs</h5><style type="text/css">
# #T_63b94_ table {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_63b94_ thead {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_63b94_ tbody {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_63b94_ th {
#   text-align: left;
#   white-space: pre-wrap;
# }
# #T_63b94_ td {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_63b94_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Percent new labels in sample</th>
#       <th class="col_heading level0 col1" >New labels</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Label column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63b94_level0_row0" class="row_heading level0 row0" >col2</th>
#       <td id="T_63b94_row0_col0" class="data row0 col0" >66.67%</td>
#       <td id="T_63b94_row0_col1" class="data row0 col1" >[4, 5]</td>
#     </tr>
#   </tbody>
# </table>
